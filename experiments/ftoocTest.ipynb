# %%
# %run "C:\\Users\\yoshi\\Music\\BlankSort-Prototypes\\src\\ftooc.py"

# %%
model=FTOOC("C:\\Users\\yoshi\\Music\\BlankSort-Prototypes\\binaries\\data\\cc.en.300.vec")
# Out:
# Database path: C:\Users\yoshi\Music\BlankSort-Prototypes\binaries\data\blanksort.database

# %%
model.getVector("VikeHacks")
# Out:
# VikeHacks
# array([ 8.92444402e-02, -8.11555460e-02, -6.08222224e-02,  4.90999930e-02,
#        -4.40111123e-02,  3.17555554e-02, -1.48077786e-01, -9.37777665e-03,
#        -6.62221946e-03,  4.83555570e-02, -1.13555463e-02, -4.36666608e-03,
#        -1.92555562e-02, -3.85444462e-02, -1.63000003e-02,  2.51777768e-02,
#         1.07644446e-01,  4.96777818e-02,  1.57777919e-03,  2.20555570e-02,
#        -4.12777811e-02, -4.59666699e-02, -1.99666694e-02, -3.12333312e-02,
#         2.14666668e-02, -8.36333334e-02, -7.01555535e-02,  1.31777786e-02,
#        -3.29888910e-02,  2.38088906e-01,  2.58999988e-02, -2.85333320e-02,
#        -2.32000016e-02,  3.93888913e-02, -3.50444466e-02, -3.53555530e-02,
#         1.20000110e-03,  7.63666630e-02, -4.52777818e-02,  4.67999987e-02,
#         5.72111160e-02, -5.77778032e-04, -8.03666636e-02, -3.68777774e-02,
#         7.87555575e-02,  5.62222209e-03, -4.11444455e-02,  2.91666687e-02,
# ...
