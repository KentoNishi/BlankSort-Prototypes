# %%
from gensim.models.fasttext import load_facebook_model

# %%
model = load_facebook_model("C:\\Users\\yoshi\\Music\\BlankSort-Prototypes\\binaries\\data\\cc.en.300.bin")
# Out:
# C:\Users\yoshi\AppData\Local\Programs\Python\Python37\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "

# %%
model.wv[""]
# Out:
# array([ 0.20582585, -0.45116234, -0.23091209,  0.22409798, -0.1318723 ,
#         0.32136446, -0.2382421 ,  0.12174245, -0.10559787,  0.06955965,
#        -0.1359461 , -0.12313921, -0.07062367, -0.04470487,  0.15641949,
#         0.02411762,  0.21718737, -0.01559836, -0.23301804, -0.20344898,
#        -0.10893124, -0.04669382, -0.01133637, -0.03011478,  0.15580973,
#        -0.01418119, -0.03603356,  0.20790264, -0.2342465 ,  0.5583219 ,
#         0.00809265, -0.06837906, -0.20318359, -0.02388947, -0.12678266,
#        -0.04815106, -0.00752214,  0.2739917 , -0.06839328,  0.16318257,
#         0.07651974, -0.08503398, -0.15309386, -0.42596   , -0.02389859,
#         0.12521671,  0.016761  ,  0.2406464 , -0.12326733,  0.06961873,
#         0.3058724 , -0.23431443,  0.11544754,  0.04655067, -0.07217104,
#        -0.16386092, -0.21977805, -0.01420746, -0.05988406, -0.1210525 ,
#         0.09170702,  0.2922311 ,  0.136958  , -0.0827653 ,  0.0161243 ,
# ...
